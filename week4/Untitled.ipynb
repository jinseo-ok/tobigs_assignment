# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
from scipy import stats
from scipy.stats import norm, skew

# %%
# 그래프에서 한글을 사용하기 위해 한글폰트를 적용
# 맥북이기에 애플고딕을 사용
plt.style.use('seaborn')
plt.rc('font', family = 'AppleGothic')
plt.rc('axes', unicode_minus = False)

def ignore_warn(*args, **kwargs):
    pass
warnings.warn = ignore_warn # warning 무시

# %%
test = pd.read_csv('./data/test_new.csv')
train = pd.read_csv('./data/train_new.csv')

# %%
train
# Out:
#       Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0      1          60       RL         65.0     8450   Pave   NaN      Reg
# 1      2          20       RL         80.0     9600   Pave   NaN      Reg
# 2      3          60       RL         68.0    11250   Pave   NaN      IR1
# 3      4          70       RL         60.0     9550   Pave   NaN      IR1
# 4      5          60       RL         84.0    14260   Pave   NaN      IR1
# ..   ...         ...      ...          ...      ...    ...   ...      ...
# 855  856          20       RL          NaN     6897   Pave   NaN      IR1
# 856  857          80       RL          NaN    10970   Pave   NaN      IR1
# 857  858          60       RL         65.0     8125   Pave   NaN      Reg
# 858  859          20       RL         80.0    10400   Pave   NaN      Reg
# 859  860          60       RL          NaN    11029   Pave   NaN      IR1
#
#     LandContour Utilities  ... PoolArea PoolQC  Fence MiscFeature MiscVal  \
# 0           Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 1           Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 2           Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 3           Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 4           Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# ..          ...       ...  ...      ...    ...    ...         ...     ...
# 855         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 856         Low    AllPub  ...        0    NaN  MnPrv         NaN       0
# 857         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 858         Lvl    AllPub  ...        0    NaN  MnPrv         NaN       0
# 859         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
#
#     MoSold YrSold  SaleType  SaleCondition  SalePrice
# 0        2   2008        WD         Normal  12.247699
# 1        5   2007        WD         Normal  12.109016
# 2        9   2008        WD         Normal  12.317171
# 3        2   2006        WD        Abnorml  11.849405
# 4       12   2008        WD         Normal  12.429220
# ..     ...    ...       ...            ...        ...
# 855      4   2010        WD         Normal  11.751950
# 856     10   2008        WD         Normal  11.898195
# 857      3   2009        WD         Normal  12.066816
# 858      6   2009        WD         Family  11.931642
# 859      8   2006        WD         Normal  12.429220
#
# [860 rows x 81 columns]

# %%
test
# Out:
#        Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0     861          50       RL         55.0     7642   Pave   NaN      Reg
# 1     862         190       RL         75.0    11625   Pave   NaN      Reg
# 2     863          20       RL         81.0     9672   Pave   NaN      Reg
# 3     864          20       RL         70.0     7931   Pave   NaN      Reg
# 4     865          20       FV         72.0     8640   Pave   NaN      Reg
# ..    ...         ...      ...          ...      ...    ...   ...      ...
# 595  1456          60       RL         62.0     7917   Pave   NaN      Reg
# 596  1457          20       RL         85.0    13175   Pave   NaN      Reg
# 597  1458          70       RL         66.0     9042   Pave   NaN      Reg
# 598  1459          20       RL         68.0     9717   Pave   NaN      Reg
# 599  1460          20       RL         75.0     9937   Pave   NaN      Reg
#
#     LandContour Utilities  ... ScreenPorch PoolArea PoolQC  Fence MiscFeature  \
# 0           Lvl    AllPub  ...           0        0    NaN  GdPrv         NaN
# 1           Lvl    AllPub  ...           0        0    NaN    NaN         NaN
# 2           Lvl    AllPub  ...           0        0    NaN  GdPrv         NaN
# 3           Lvl    AllPub  ...           0        0    NaN  GdPrv         NaN
# 4           Lvl    AllPub  ...           0        0    NaN    NaN         NaN
# ..          ...       ...  ...         ...      ...    ...    ...         ...
# 595         Lvl    AllPub  ...           0        0    NaN    NaN         NaN
# 596         Lvl    AllPub  ...           0        0    NaN  MnPrv         NaN
# 597         Lvl    AllPub  ...           0        0    NaN  GdPrv        Shed
# 598         Lvl    AllPub  ...           0        0    NaN    NaN         NaN
# 599         Lvl    AllPub  ...           0        0    NaN    NaN         NaN
#
#     MiscVal MoSold  YrSold  SaleType  SaleCondition
# 0         0      6    2007        WD         Normal
# 1         0      4    2010        WD         Normal
# 2         0      5    2010        WD         Normal
# 3         0      7    2009        WD         Normal
# 4         0      5    2008       New        Partial
# ..      ...    ...     ...       ...            ...
# 595       0      8    2007        WD         Normal
# 596       0      2    2010        WD         Normal
# 597    2500      5    2010        WD         Normal
# 598       0      4    2010        WD         Normal
# 599       0      6    2008        WD         Normal
#
# [600 rows x 80 columns]

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 860 entries, 0 to 859
# Data columns (total 81 columns):
# Id               860 non-null int64
# MSSubClass       860 non-null int64
# MSZoning         860 non-null object
# LotFrontage      713 non-null float64
# LotArea          860 non-null int64
# Street           860 non-null object
# Alley            61 non-null object
# LotShape         860 non-null object
# LandContour      860 non-null object
# Utilities        860 non-null object
# LotConfig        860 non-null object
# LandSlope        860 non-null object
# Neighborhood     860 non-null object
# Condition1       860 non-null object
# Condition2       860 non-null object
# BldgType         860 non-null object
# HouseStyle       860 non-null object
# OverallQual      860 non-null int64
# OverallCond      860 non-null int64
# YearBuilt        860 non-null int64
# YearRemodAdd     860 non-null int64
# RoofStyle        860 non-null object
# RoofMatl         860 non-null object
# Exterior1st      860 non-null object
# Exterior2nd      860 non-null object
# MasVnrType       857 non-null object
# MasVnrArea       857 non-null float64
# ExterQual        860 non-null object
# ExterCond        860 non-null object
# Foundation       860 non-null object
# BsmtQual         840 non-null object
# BsmtCond         840 non-null object
# BsmtExposure     840 non-null object
# BsmtFinType1     840 non-null object
# BsmtFinSF1       860 non-null int64
# BsmtFinType2     839 non-null object
# BsmtFinSF2       860 non-null int64
# BsmtUnfSF        860 non-null int64
# TotalBsmtSF      860 non-null int64
# Heating          860 non-null object
# HeatingQC        860 non-null object
# CentralAir       860 non-null object
# Electrical       860 non-null object
# 1stFlrSF         860 non-null int64
# 2ndFlrSF         860 non-null int64
# LowQualFinSF     860 non-null int64
# GrLivArea        860 non-null int64
# BsmtFullBath     860 non-null int64
# BsmtHalfBath     860 non-null int64
# FullBath         860 non-null int64
# HalfBath         860 non-null int64
# BedroomAbvGr     860 non-null int64
# KitchenAbvGr     860 non-null int64
# KitchenQual      860 non-null object
# TotRmsAbvGrd     860 non-null int64
# Functional       860 non-null object
# Fireplaces       860 non-null int64
# FireplaceQu      461 non-null object
# GarageType       811 non-null object
# GarageYrBlt      811 non-null float64
# GarageFinish     811 non-null object
# GarageCars       860 non-null int64
# GarageArea       860 non-null int64
# GarageQual       811 non-null object
# GarageCond       811 non-null object
# PavedDrive       860 non-null object
# WoodDeckSF       860 non-null int64
# OpenPorchSF      860 non-null int64
# EnclosedPorch    860 non-null int64
# 3SsnPorch        860 non-null int64
# ScreenPorch      860 non-null int64
# PoolArea         860 non-null int64
# PoolQC           2 non-null object
# Fence            162 non-null object
# MiscFeature      37 non-null object
# MiscVal          860 non-null int64
# MoSold           860 non-null int64
# YrSold           860 non-null int64
# SaleType         860 non-null object
# SaleCondition    860 non-null object
# SalePrice        860 non-null float64
# dtypes: float64(4), int64(34), object(43)
# memory usage: 544.3+ KB
