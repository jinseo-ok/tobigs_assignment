# %%
import os
import pandas as pd
import numpy as np

# %%
base_dir = '/Users/jinseok/jupyter/투빅스/tobigs_assignment/Week1/전처리&EDA'
excel_file = 'dataset.xlsx'

excel_dir = os.path.join(base_dir, excel_file)

# %%
df = pd.read_excel( excel_dir, encoding = 'cp949')

# %%
df.head()
# Out:
#    Unnamed: 0  Auction_key Auction_class Bid_class  Claim_price  \
# 0           0         2687            임의        개별   1766037301
# 1           1         2577            임의        일반    152946867
# 2           2         2197            임의        개별     11326510
# 3           3         2642            임의        일반    183581724
# 4           4         1958            강제        일반     45887671
#
#   Appraisal_company       Appraisal_date  Auction_count  \
# 0              정명감정  2017-07-26 00:00:00              2
# 1               희감정  2016-09-12 00:00:00              2
# 2              혜림감정  2016-11-22 00:00:00              3
# 3              신라감정  2016-12-13 00:00:00              2
# 4              나라감정  2016-03-07 00:00:00              2
#
#    Auction_miscarriage_count  Total_land_gross_area  ...     point.x  \
# 0                          1                12592.0  ...  129.137048
# 1                          1                42478.1  ...  129.145068
# ...

# %% [markdown]
# # 1. 범주형 변수

# %%
# 변수파악

# %%
column_dict = {'Auction_key': '경매 아파트 고유 키값',
               'Auction_class': '경매구분 강제경매',
               'Bid_class': '입찰구분(일반/개별/일괄)',
               'Claim_price': '경매 신청인의 청구 금액',
                'Appraisal_company': '감정사',
                'Appraisal_date': '감정일자',
                'Auction_count': '총경매횟수',
                'Auction_miscarriage_count': '총유찰횟수',
                'Total_land_gross_area': '총토지전체면적(㎡)',
                'Total_land_real_area': '총토지실면적(㎡)',
                'Total_land_auction_area': '총토지경매면적(㎡)',
                'Total_building_area': '총건물면적(㎡)',
                'Total_building_auction_area': '총건물경매면적(㎡)',
                'Total_appraisal_price': '총감정가',
                'Minimum_sales_price': '최저매각가격, 입찰 시 입찰인이 최저로 제시해야만 하는 금액',
                'First_auction_date': '최초경매일',
                'Final_auction_date': '최종경매일',
                'Final_result': '최종결과',
                'Creditor': '채권자, 경매 신청인',
                'addr_do': '주소_시도',
                'addr_si': '주소_시군구',
                'addr_dong': '주소_읍면동',
                'addr_li': '주소_리',
                'addr_san': '주소_산번지 여부(Y/N)',
                'addr_bunji1': '주소_번지1',
                'addr_bunji2': '주소_번지2',
                'addr_etc': '주소_기타주소',
                'Apartment_usage': '건물(토지)의 대표 용도',
                'Preserve_regist_date': '보존등기일, 건물을 신축하고 처음으로 등기',
                'Total_floor': '총층수',
                'Current_floor': '현재층수',
                'Specific': '기타_특이사항',
                'Share_auction_YorN': '지분경매 여부(Y/N)',
                'road_name': '도로명주소_도로명',
                'road_bunji1': '도로명주소_번지1',
                'road_bunji2': '도로명주소_번지2',
                'Close_date': '종국일자',
                'Close_result': '종국결과',
                'point.y': '위도',
                'point.x': '경도',
                'Hammer_price': '낙찰가',
               'season' : '낙찰계절',
               'period' : '총경매기간',
               'age' : '건물연혁',
               'pprice' : '평당낙찰가격',
               'range' : '감정가 와 낙찰가 차이',
               'aprice' : '평당감정가격',
               'term' : '감정일자 최초경매일 사이기간'
    }

# %%
column_dict
# Out:
# {'Auction_key': '경매 아파트 고유 키값',
#  'Auction_class': '경매구분 강제경매',
#  'Bid_class': '입찰구분(일반/개별/일괄)',
#  'Claim_price': '경매 신청인의 청구 금액',
#  'Appraisal_company': '감정사',
#  'Appraisal_date': '감정일자',
#  'Auction_count': '총경매횟수',
#  'Auction_miscarriage_count': '총유찰횟수',
#  'Total_land_gross_area': '총토지전체면적(㎡)',
#  'Total_land_real_area': '총토지실면적(㎡)',
#  'Total_land_auction_area': '총토지경매면적(㎡)',
#  'Total_building_area': '총건물면적(㎡)',
#  'Total_building_auction_area': '총건물경매면적(㎡)',
#  'Total_appraisal_price': '총감정가',
#  'Minimum_sales_price': '최저매각가격, 입찰 시 입찰인이 최저로 제시해야만 하는 금액',
#  'First_auction_date': '최초경매일',
#  'Final_auction_date': '최종경매일',
#  'Final_result': '최종결과',
#  'Creditor': '채권자, 경매 신청인',
#  'addr_do': '주소_시도',
#  'addr_si': '주소_시군구',
#  'addr_dong': '주소_읍면동',
#  'addr_li': '주소_리',
#  'addr_san': '주소_산번지 여부(Y/N)',
#  'addr_bunji1': '주소_번지1',
#  'addr_bunji2': '주소_번지2',
#  'addr_etc': '주소_기타주소',
#  'Apartment_usage': '건물(토지)의 대표 용도',
# ...

# %% [markdown]
# ## 1-1. 범주형 변수 인코딩
#
#    - 'Auction_class': '경매구분 강제경매'
#    - 'Bid_class': '입찰구분(일반/개별/일괄)'
#    - 'addr_san': '주소_산번지 여부(Y/N)'
#    - 'Share_auction_YorN': '지분경매 여부(Y/N)'

# %%
df[['Auction_class', 'Bid_class', 'addr_san', 'Share_auction_YorN']]
# Out:
#      Auction_class Bid_class addr_san Share_auction_YorN
# 0               임의        개별        N                  N
# 1               임의        일반        N                  N
# 2               임의        개별        N                  N
# 3               임의        일반        N                  N
# 4               강제        일반        N                  N
# ...            ...       ...      ...                ...
# 1928            강제        일반        N                  N
# 1929            임의        일반        N                  N
# 1930            임의        일반        N                  N
# 1931            강제        일반        N                  N
# 1932            임의        일반        N                  N
#
# [1933 rows x 4 columns]

# %% [markdown]
#    - 'Auction_class': '경매구분 강제경매'

# %%
# 몇 개의 범주형으로 구성되어있는지 확인
# 임의 1439개, 강제 494개
df['Auction_class'].value_counts()
# Out:
# 임의    1439
# 강제     494
# Name: Auction_class, dtype: int64

# %%
# 임의 -> 1
# 강제 -> 0
def getEncoding(x):
    if x == '임의':
        x = 1
    else:
        x = 0
    return x

# %%
df.Auction_class = df.Auction_class.apply(getEncoding)

# %%
df['Auction_class'].value_counts()
# Out:
# 1    1439
# 0     494
# Name: Auction_class, dtype: int64

# %% [markdown]
#    - 'Bid_class': '입찰구분(일반/개별/일괄)'

# %%
# 일반 1796개, 개별 125개, 일괄 12개
df['Bid_class'].value_counts()
# Out:
# 일반    1796
# 개별     125
# 일괄      12
# Name: Bid_class, dtype: int64

# %%
# One-hot 인코딩
dum = pd.get_dummies(df.Bid_class, prefix='Bid')

# %%
df = pd.concat([df,dum], axis=1)

# %% [markdown]
#    - 'addr_san': '주소_산번지 여부(Y/N)'

# %%
# Y 1912개, N 21개
df['addr_san'].value_counts()
# Out:
# N    1912
# Y      21
# Name: addr_san, dtype: int64

# %%
# Y -> 1
# N -> 0
def getEncoding(x):
    if x == 'Y':
        x = 1
    else:
        x = 0
    return x

# %%
df.addr_san = df.addr_san.apply(getEncoding)

# %%
df['addr_san'].value_counts()
# Out:
# 0    1912
# 1      21
# Name: addr_san, dtype: int64

# %% [markdown]
#    - 'Share_auction_YorN': '지분경매 여부(Y/N)'

# %%
# Y 79개, N 1854개
df['Share_auction_YorN'].value_counts()
# Out:
# N    1854
# Y      79
# Name: Share_auction_YorN, dtype: int64

# %%
df.Share_auction_YorN = df.Share_auction_YorN.apply(getEncoding)

# %%
df['Share_auction_YorN'].value_counts()
# Out:
# 0    1854
# 1      79
# Name: Share_auction_YorN, dtype: int64

# %% [markdown]
# ## 1-2. 범주형 변수 시각화

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# 그래프에서 한글을 사용하기 위해 한글폰트를 적용
# 맥북이기에 애플고딕을 사용
plt.style.use('seaborn') # seaborn 스타일로 변환
plt.rc('font', family='AppleGothic')
plt.rc('axes', unicode_minus=False)

# %% [markdown]
#    - 'Auction_class': '경매구분' 별 낙찰가 비율
#    - 'Bid_class' : 입찰구분(일반/개별/일괄) 별 낙찰가 비율
#    - 'addr_san' : 주소_산번지 여부 별 낙찰가 비율

# %%
df['Hammer_price'].describe()
# Out:
# count    1.933000e+03
# mean     4.726901e+08
# std      5.574493e+08
# min      6.303000e+06
# 25%      1.975550e+08
# 50%      3.544500e+08
# 75%      5.599000e+08
# max      1.515100e+10
# Name: Hammer_price, dtype: float64

# %%
# hammer_price 분포가 너무 넓어 시각화가 너무 넓게 나타남
# hammer_price < 10억 인 경우가 1769 개, 90% 이상임
df2 = df[df['Hammer_price'] < 1000000000]

# %%
df2
# Out:
#       Unnamed: 0  Auction_key  Auction_class Bid_class  Claim_price  \
# 0              0         2687              1        개별   1766037301
# 1              1         2577              1        일반    152946867
# 2              2         2197              1        개별     11326510
# 3              3         2642              1        일반    183581724
# 4              4         1958              0        일반     45887671
# ...          ...          ...            ...       ...          ...
# 1928        1928         1567              0        일반    280000000
# 1929        1929         1295              1        일반    200000000
# 1930        1930          254              1        일반    354805459
# 1931        1931         1486              0        일반     80000000
# 1932        1932          937              1        일반    180000000
#
#      Appraisal_company       Appraisal_date  Auction_count  \
# 0                 정명감정  2017-07-26 00:00:00              2
# ...

# %%
# 'Auction_class', 경매구분 별 그래프
# 'Bid class', 입찰구분 별 그래프

auc = plt.subplot(1,2,1)
auc = sns.kdeplot(df2.query('Auction_class == 1')['Hammer_price'], color = "red",shade= True)
auc = sns.kdeplot(df2.query('Auction_class == 0')['Hammer_price'], color = 'green', shade = True)
auc.set_xlabel('낙찰가')
auc.set_ylabel('비율')
auc.set_title('경매구분 별 낙찰가 비율')
auc = auc.legend(['임의','강제'])


bid = plt.subplot(1,2,2)
bid = sns.kdeplot(df2.query('Bid_개별 == 1')['Hammer_price'], color = "red",shade= True)
bid = sns.kdeplot(df2.query('Bid_일괄 == 1')['Hammer_price'], color = 'green', shade = True)
bid = sns.kdeplot(df2.query('Bid_일반 == 1')['Hammer_price'], color = 'yellow', shade = True)
bid.set_xlabel('낙찰가')
bid.set_ylabel('비율')
bid.set_title('입찰구분 별 낙찰가 비율')
bid = bid.legend(['개별','일반','일괄'])

plt.tight_layout()
plt.show()

# %%
# 'addr_san', 주소_산번지 여부(Y/N) 별 낙찰가 비율
# 'Share_auction_YorN', 지분경매 여부(Y/N) 별 낙찰가 비율 

add = plt.subplot(1,2,1)
add = sns.distplot(df2.query('addr_san == 1')['Hammer_price'])
add = sns.distplot(df2.query('addr_san == 0')['Hammer_price'])
add.set_xlabel('낙찰가')
add.set_ylabel('비율')
add.set_title('주소_산번지 여부 별 낙찰가 비율')
add = add.legend(['Y', 'N'])

sha = plt.subplot(1,2,2)
sha = sns.distplot(df2.query('Share_auction_YorN == 1')['Hammer_price'])
sha = sns.distplot(df2.query('Share_auction_YorN == 0')['Hammer_price'])
sha.set_xlabel('낙찰가')
sha.set_ylabel('비율')
sha.set_title('지분경매 여부 별 낙찰가 비율')
sha = sha.legend(['Y', 'N'])

plt.tight_layout()
plt.show()

# %%
# 'season', 낙찰 계절 별 아파트층수 와 낙찰가 상관관계
lm = sns.lmplot(x="Current_floor", y='Hammer_price', hue = 'season', data = df2, size = 10)
fig = lm.fig
fig.suptitle('계절 별 아파트 층수와 낙찰가 상관관계')
plt.subplots_adjust(top=0.95)
plt.show()

# %% [markdown]
# # 2. 선형회귀분석

# %%
from sklearn.linear_model import LinearRegression

# %%
# Total_land_auction_area == 0 인 경우 때문에 pprice 와 aprice 에서 inf 를 가지는 로우가 생겨남
# 정규화 하는 과정에서 오류가 발생됨
# df 에서 처음부터 Total_land_auction_area == 0 인 값을 제외하고 df_new 생성
# week1 때 생성한 새로운 변수에 대한 회귀분석 진행
df_temp = df[df['Total_land_auction_area'] != 0]
df_new = df_temp[['season', 'period', 'floor_loc', 'age', 'pprice', 'range', 'aprice', 'term', 'Hammer_price']]

# %% [markdown]
#    ## 2-1. 정규화

# %%
# season, 계절 인코팅
# One-hot 인코딩
dum = pd.get_dummies(df_new.season, prefix='계절')

# %%
df_new = pd.concat([ df_new, dum ], axis=1)

# %%
# 인덱스 재설정 (데이터프레임 행 결합할 때 오류 방지)
df_new = df_new.reset_index(drop = False, inplace = False)

# %%
# 최소값(Min)과 최대값(Max)을 사용해서 '0~1' 사이의 범위(range)로 데이터를 표준화해주는 MinMax 정규화 사용
# 이상치, 특이값에 덜 민감한" 중앙값(median)과 IQR(Inter-Quartile Range)을 이용해서 척도를 표준화하는 RobustScaler 사용
from sklearn.preprocessing import minmax_scale, RobustScaler

# %%
# period(총경매기간), age(건물연혁), term(감정일자와 최초경매일 기간)
# 기간 에 있어서는 특정 이상치가 없고 어느정도 데이터가 고르게 분포되어 있다고 생각하여 MinMax 사용
minmax_column = df_new[['period', 'age', 'term']]

# %%
X_MinMax_scaled = minmax_scale(minmax_column, axis=0, copy=True)

# %%
df_minmax = pd.DataFrame(X_MinMax_scaled, columns = ['period', 'age', 'term'])

# %%
df_new[['period', 'age', 'term']] = df_minmax[['period', 'age', 'term']]

# %%
# pprice(평당낙찰가격), range(감정가와 낙찰가 차이),aprice(평당감정가격)
# week1 에서 Hammer_price 가 극도로 높은 경우가 있어 Robust 사용
robust_column = df_new[['pprice', 'range', 'aprice']]

# %%
x_RobustScaler = RobustScaler().fit_transform(robust_column)

# %%
df_robust = pd.DataFrame(x_RobustScaler, columns = ['pprice', 'range', 'aprice'])

# %%
df_new[['pprice', 'range', 'aprice']] = df_robust[['pprice', 'range', 'aprice']]

# %%
df_new.head()
# Out:
#    index season    period  floor_loc       age    pprice     range    aprice  \
# 0      0      봄  0.018051      0.111  0.008737  1.199322  2.025056  1.462825
# 1      1     겨울  0.018051      0.729  0.006062  4.776844  2.737419  5.576252
# 2      2     가을  0.039711      0.933  0.027458 -0.965255  0.595224 -0.983998
# 3      3     겨울  0.054152      0.550  0.017575 -0.228979  0.762634 -0.148754
# 4      4     여름  0.014440      1.000  0.017161 -0.715484  0.190673 -0.737435
#
#        term  Hammer_price  계절_가을  계절_겨울  계절_봄  계절_여름
# 0  0.473865     760000000      0      0     1      0
# 1  0.450798     971889999      0      1     0      0
# 2  0.485153      93399999      1      0     0      0
# 3  0.478037     256899000      0      1     0      0
# 4  0.453988     158660000      0      0     0      1

# %%
# index 와 season 칼럼 삭제
df_new.drop(['index', 'season'], axis=1, inplace = True)

# %%
df_new.head()
# Out:
#      period  floor_loc       age    pprice     range    aprice      term  \
# 0  0.018051      0.111  0.008737  1.199322  2.025056  1.462825  0.473865
# 1  0.018051      0.729  0.006062  4.776844  2.737419  5.576252  0.450798
# 2  0.039711      0.933  0.027458 -0.965255  0.595224 -0.983998  0.485153
# 3  0.054152      0.550  0.017575 -0.228979  0.762634 -0.148754  0.478037
# 4  0.014440      1.000  0.017161 -0.715484  0.190673 -0.737435  0.453988
#
#    Hammer_price  계절_가을  계절_겨울  계절_봄  계절_여름
# 0     760000000      0      0     1      0
# 1     971889999      0      1     0      0
# 2      93399999      1      0     0      0
# 3     256899000      0      1     0      0
# 4     158660000      0      0     0      1

# %% [markdown]
# ## 2-2. EDA

# %%
x = df_new.drop('Hammer_price', axis=1)
y = df_new.Hammer_price

# %%
# pprice 와 aprice와 높은 상관관계를 가짐
x.corr()
# Out:
#              period  floor_loc       age    pprice     range    aprice  \
# period     1.000000   0.010888  0.355504 -0.015349  0.084223  0.038118
# floor_loc  0.010888   1.000000  0.020997  0.101353 -0.023449  0.106795
# age        0.355504   0.020997  1.000000 -0.023352  0.201636  0.010323
# pprice    -0.015349   0.101353 -0.023352  1.000000  0.040703  0.981557
# range      0.084223  -0.023449  0.201636  0.040703  1.000000  0.097908
# aprice     0.038118   0.106795  0.010323  0.981557  0.097908  1.000000
# term      -0.099954   0.025893  0.079421  0.008556 -0.005206 -0.002122
# 계절_가을      0.009576  -0.030201 -0.041206 -0.044300 -0.034040 -0.060484
# 계절_겨울     -0.052509  -0.024502 -0.027257  0.000790  0.022683 -0.002741
# 계절_봄       0.077061   0.032093  0.067423 -0.010735 -0.000446  0.000914
# 계절_여름     -0.017507   0.021476  0.004350  0.041740  0.004200  0.048278
#
#                term     계절_가을     계절_겨울      계절_봄     계절_여름
# ...

# %%
# pprice 와 aprice와 높은 상관관계를 가짐을 그래프로 확인 ㄹ가능
sns.pairplot(x)

# %%
# VIF확인하기
from statsmodels.stats.outliers_influence import variance_inflation_factor

# %%
# Out:
# 11

# %%
# 계절_여름, 계절_겨울, aprice, pprice, 계절_봄, 계절_가을 이 VIF가 10 이상
vif = pd.DataFrame()
vif["VIF Factor"] = [variance_inflation_factor(x.values, i) for i in range(x.shape[1])] # x의 열 개수만큼 for문 실행
vif["features"] = x.columns
vif.sort_values(["VIF Factor"], ascending=[False])
# Out:
#     VIF Factor   features
# 10   58.579533      계절_여름
# 8    54.460979      계절_겨울
# 5    32.880060     aprice
# 3    32.517296     pprice
# 9    30.762920       계절_봄
# 7    27.154463      계절_가을
# 0     1.241538     period
# 2     1.210061        age
# 4     1.139376      range
# 6     1.030119       term
# 1     1.016486  floor_loc

# %% [markdown]
# ## 2-3. Model

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
import sklearn as sk # MSE

# %%
# train, test 로 데이터 분할
# train 과 test = 8 : 2
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=0)

# %%
# 모델 생성
# train data에 fit시킴
model = LinearRegression()
model.fit(x_train, y_train) # model에 x,y 값을 각각 적용시킴
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
# train 모델의 R-square
model.score(x_train, y_train)
# Out:
# 0.6975657258526122

# %%
# MSE
sk.metrics.mean_squared_error(y_train, model.predict(x_train))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-344-d2224f414256> in <module>
#       1 #
# ----> 2 sk.metrics.mean_squared_error(y_train, model.predict(x_train))
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/sklearn/linear_model/_base.py in predict(self, X)
#     223             Returns predicted values.
#     224         """
# --> 225         return self._decision_function(X)
#     226
#     227     _preprocess_data = staticmethod(_preprocess_data)
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/sklearn/linear_model/_base.py in _decision_function(self, X)
#     207         X = check_array(X, accept_sparse=['csr', 'csc', 'coo'])
#     208         return safe_sparse_dot(X, self.coef_.T,
# --> 209                                dense_output=True) + self.intercept_
#     210
# ...

# %%
# 추정된 회귀계수
model.coef_
# Out:
# array([ 1.89724850e+08, -4.87081885e+07, -1.96747645e+07,  6.54459678e+08,
#         4.32419437e+07, -3.94417587e+08,  7.30404535e+07,  1.21855578e+06,
#        -1.49373267e+06,  1.14012017e+07, -1.11260248e+07])

# %%
# 절편값
model.intercept_
# Out:
# 373026659.8937523

# %%
# test 데이터 예측
model.predict(x_test)
# Out:
# array([2.71071301e+08, 9.97129860e+08, 3.85441276e+08, 3.20683827e+08,
#        3.38523829e+08, 6.72295074e+08, 2.70968177e+08, 2.94089420e+08,
#        3.06654336e+08, 3.26026220e+08, 1.07121470e+09, 3.99516652e+08,
#        2.84763521e+08, 5.63680001e+08, 2.72465799e+08, 5.89210801e+08,
#        1.06113003e+09, 8.61787069e+08, 1.57338032e+08, 2.46007206e+08,
#        3.88886382e+08, 2.58678389e+08, 3.48626272e+08, 3.22945848e+08,
#        9.54781030e+08, 3.83126598e+08, 2.43781639e+08, 4.08616568e+08,
#        3.31398152e+08, 3.85102279e+08, 4.94179037e+08, 5.07446053e+08,
#        1.51273529e+08, 5.06240539e+08, 4.75263148e+08, 5.14962602e+08,
#        2.06847232e+08, 3.66795448e+08, 4.11759699e+08, 5.50510365e+08,
#        3.34070214e+08, 4.69229355e+08, 4.71700398e+08, 4.00451555e+08,
#        2.60034890e+08, 3.97892128e+08, 8.56714858e+08, 3.69842594e+08,
#        7.69932403e+08, 2.54868491e+08, 4.70936163e+08, 9.19516576e+08,
# ...

# %%
# test 데이터 R-square
model.score(x_test, y_test)
# Out:
# 0.3997237781418369

# %%
import statsmodels.api as sm

# %%
# 단계적선택법 을 적용해보고 싶어, 레퍼런스를 참고하여 적용해봄
# range, pprice, aprice 가 가장 좋은 설명력을 가지는 변수의 집합으로 나왔는데 맞는지는 모르겠음..
# 출처 : https://github.com/AakkashVijayakumar/stepwise-regression/tree/master/stepwise_regression
# 출처 : https://pypi.org/project/stepwise-regression/#files
def stepwise_selection(X, y, 
                       initial_list=[], 
                       threshold_in=0.01, 
                       threshold_out = 0.05, 
                       verbose=True):
    """ Perform a forward-backward feature selection 
    based on p-value from statsmodels.api.OLS
    Arguments:
        X - pandas.DataFrame with candidate features
        y - list-like with the target
        initial_list - list of features to start with (column names of X)
        threshold_in - include a feature if its p-value < threshold_in
        threshold_out - exclude a feature if its p-value > threshold_out
        verbose - whether to print the sequence of inclusions and exclusions
    Returns: list of selected features 
    Always set threshold_in < threshold_out to avoid infinite looping.
    See https://en.wikipedia.org/wiki/Stepwise_regression for the details
    """
    included = list(initial_list)
    while True:
        changed=False
        # forward step
        excluded = list(set(X.columns)-set(included))
        new_pval = pd.Series(index=excluded)
        for new_column in excluded:
            model = sm.OLS(y, sm.add_constant(pd.DataFrame(X[included+[new_column]]))).fit()
            new_pval[new_column] = model.pvalues[new_column]
        best_pval = new_pval.min()
        if best_pval < threshold_in:
            best_feature = new_pval.argmin()
            included.append(best_feature)
            changed=True
            if verbose:
                print('Add  {:30} with p-value {:.6}'.format(best_feature, best_pval))

        # backward step
        model = sm.OLS(y, sm.add_constant(pd.DataFrame(X[included]))).fit()
        # use all coefs except intercept
        pvalues = model.pvalues.iloc[1:]
        worst_pval = pvalues.max() # null if pvalues is empty
        if worst_pval > threshold_out:
            changed=True
            worst_feature = pvalues.argmax()
            included.remove(worst_feature)
            if verbose:
                print('Drop {:30} with p-value {:.6}'.format(worst_feature, worst_pval))
        if not changed:
            break
    return included

result = stepwise_selection(x, y)

print('resulting features:')
print(result)
# Out:
# Add  range                          with p-value 2.55396e-213
# Add  pprice                         with p-value 2.5025e-199
# Add  aprice                         with p-value 5.8756e-40
# resulting features:
# ['range', 'pprice', 'aprice']
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/ipykernel_launcher.py:30: FutureWarning:
# The current behaviour of 'Series.argmin' is deprecated, use 'idxmin'
# instead.
# The behavior of 'argmin' will be corrected to return the positional
# minimum in the future. For now, use 'series.values.argmin' or
# 'np.argmin(np.array(values))' to get the position of the minimum
# row.

# %%
# stepwise 결과를 바탕으로 다시 한번 선형회귀 진행
df_step = df_new[['range', 'pprice', 'aprice', 'Hammer_price']]

# %%
x = df_step.drop('Hammer_price', axis=1)
y = df_step.Hammer_price

# %%
model = LinearRegression()
model.fit(x, y)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
# 66.35% 의 설명력을 보여줌
model.score(x, y)
# Out:
# 0.6635020669568741

# %%
model.coef_
# Out:
# array([ 4.31066744e+07,  6.59758366e+08, -4.01922446e+08])

# %%
# MSE
sk.metrics.mean_squared_error(y, model.predict(x))
# Out:
# 1.0637734215365896e+17

# %% [markdown]
# ## 2-4. 직접 계산

# %%
from numpy.linalg import inv

# %%
def estimateBeta(x, y):
    xT = np.transpose(x)
    a = np.dot(xT, x)
    aI = inv(a)
    b = np.dot(xT, y)
    
    beta_hat = np.dot(aI,b)
    return beta_hat

# %%
x = x.values
y = y.values

# %%
estimateBeta(x,y)
# Out:
# array([ 4.47455058e+07,  6.61538242e+08, -3.35564217e+08])

# %%
def estimateMSE(x, y):
    y_hat = model.predict(x)
    square = [np.square(y_i - y_hat_i) for y_i, y_hat_i in zip(y, y_hat)] # y 값과 y 예측값 차이를 list 형태로 square 에 저장
    SSE = sum(square) # 잔차들의 합
    print('SSE :', SSE)
    df = len(y) + x.shape[1] - 1 # 자유도
    MSE = SSE / df # SSE / df
    print('MSE :', MSE)
    return

# %%
estimateMSE(x, y)
# Out:
# SSE : 2.00946799328262e+20
# MSE : 1.0626483306624114e+17

# %% [raw]
# sklearn 을 이용한 결과값이랑 직접 행렬을 계산해서 얻은 값이랑 같음을 알수있음
